# %%
import pandas as pd 
import numpy as np

# %%
my_df = pd.DataFrame(np.random.randint(1,45,200), columns = {'Value'})

# %%
my_df
# Out:
#      Value
# 0       31
# 1       12
# 2       42
# 3       17
# 4       26
# ..     ...
# 195     12
# 196     10
# 197     16
# 198     31
# 199     44
#
# [200 rows x 1 columns]

# %% [markdown]
# # TO_ METHODS

# %%
to_methods = [x for x in dir(pd.DataFrame) if str(x).startswith('to_') == True]
to_methods
# Out:
# ['to_clipboard',
#  'to_csv',
#  'to_dict',
#  'to_excel',
#  'to_feather',
#  'to_gbq',
#  'to_hdf',
#  'to_html',
#  'to_json',
#  'to_latex',
#  'to_markdown',
#  'to_numpy',
#  'to_parquet',
#  'to_period',
#  'to_pickle',
#  'to_records',
#  'to_sql',
#  'to_stata',
#  'to_string',
#  'to_timestamp',
#  'to_xarray']

# %% [markdown]
# ## to_clipboard

# %% [markdown]
# Hafızada olan DataFrame'i clipboard'a kopyalar

# %%
my_df.to_clipboard()

# %% [raw]
# 	Value
# 0	31
# 1	12
# 2	42
# 3	17
# 4	26
# 5	17
# 6	30
# 7	43
# 8	20
# 9	24
# 10	42
# 11	34
# 12	20
# 13	1
# 14	14
# 15	10
# 16	16
# 17	38
# 18	10
# 19	31
# 20	20
# 21	1
# 22	35
# 23	42
# 24	15
# 25	10
# 26	23
# 27	9
# 28	9
# 29	42
# 30	18
# 31	3
# 32	16
# 33	34
# 34	5
# 35	4
# 36	35
# 37	20
# 38	16
# 39	39
# 40	4
# 41	40
# 42	33
# 43	14
# 44	32
# 45	5
# 46	15
# 47	32
# 48	7
# 49	19
# 50	15
# 51	11
# 52	35
# 53	5
# 54	33
# 55	32
# 56	32
# 57	5
# 58	28
# 59	7
# 60	2
# 61	1
# 62	42
# 63	37
# 64	19
# 65	1
# 66	38
# 67	33
# 68	28
# 69	17
# 70	34
# 71	5
# 72	35
# 73	28
# 74	16
# 75	6
# 76	43
# 77	6
# 78	12
# 79	35
# 80	36
# 81	16
# 82	6
# 83	3
# 84	2
# 85	36
# 86	12
# 87	8
# 88	5
# 89	39
# 90	35
# 91	13
# 92	27
# 93	15
# 94	38
# 95	2
# 96	22
# 97	23
# 98	13
# 99	33
# 100	37
# 101	3
# 102	17
# 103	32
# 104	5
# 105	38
# 106	15
# 107	9
# 108	23
# 109	33
# 110	40
# 111	18
# 112	25
# 113	20
# 114	17
# 115	33
# 116	12
# 117	28
# 118	15
# 119	5
# 120	25
# 121	30
# 122	19
# 123	41
# 124	23
# 125	33
# 126	38
# 127	23
# 128	5
# 129	32
# 130	10
# 131	36
# 132	2
# 133	5
# 134	35
# 135	5
# 136	8
# 137	3
# 138	42
# 139	42
# 140	25
# 141	17
# 142	29
# 143	22
# 144	15
# 145	13
# 146	9
# 147	1
# 148	31
# 149	10
# 150	7
# 151	8
# 152	4
# 153	37
# 154	26
# 155	15
# 156	1
# 157	10
# 158	15
# 159	41
# 160	43
# 161	33
# 162	14
# 163	2
# 164	24
# 165	23
# 166	26
# 167	34
# 168	18
# 169	24
# 170	13
# 171	17
# 172	35
# 173	14
# 174	12
# 175	15
# 176	31
# 177	42
# 178	23
# 179	17
# 180	4
# 181	20
# 182	11
# 183	39
# 184	44
# 185	6
# 186	8
# 187	18
# 188	29
# 189	17
# 190	20
# 191	9
# 192	19
# 193	43
# 194	1
# 195	12
# 196	10
# 197	16
# 198	31
# 199	44

# %% [markdown]
# ## to_csv

# %%
my_df.to_csv()

# %% [markdown]
# ## to_dict

# %% [markdown]
# ## to_excel

# %% [markdown]
# ## to_feather

# %% [markdown]
# ## to_gbq

# %% [markdown]
# ## to_hdf

# %% [markdown]
# ## to_html

# %% [markdown]
# ## to_json

# %% [markdown]
# ## to_latex

# %% [markdown]
# ## to_markdown

# %% [markdown]
# ## to_numpy

# %% [markdown]
# ## to_parquet

# %% [markdown]
# ## to_period

# %% [markdown]
# ## to_pickle

# %% [markdown]
# ## to_records

# %% [markdown]
# ## to_sql

# %% [markdown]
# ## to_stata

# %% [markdown]
# ## to_string

# %% [markdown]
# ## to_timestamp

# %% [markdown]
# ## to_xarray
